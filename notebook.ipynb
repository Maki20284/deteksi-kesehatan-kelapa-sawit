# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# %%
model = YOLO("yolov12_sawit_v2.pt")
model.export(format="torchscript")
# Out:
# Ultralytics 8.3.160  Python-3.11.9 torch-2.7.1+cpu CPU (13th Gen Intel Core(TM) i7-13620H)
#  ProTip: Export to OpenVINO format for best performance on Intel CPUs. Learn more at https://docs.ultralytics.com/integrations/openvino/
#
# PyTorch: starting from 'yolov12_sawit.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 10, 8400) (5.1 MB)
#
# TorchScript: starting export with torch 2.7.1+cpu...
# TorchScript: export success  3.1s, saved as 'yolov12_sawit.torchscript' (10.5 MB)
#
# Export complete (4.7s)
# Results saved to D:\pindah file\college\PI\sawit
# Predict:         yolo predict task=detect model=yolov12_sawit.torchscript imgsz=640
# Validate:        yolo val task=detect model=yolov12_sawit.torchscript imgsz=640 data=/kaggle/working/Oil palm tree Health detection.v1i.yolov12/data.yaml
# Visualize:       https://netron.app
# 'yolov12_sawit.torchscript'

# %%
image_path = "test_image.jpg"

# %%
results = model(image_path)
results
# Out:
# image 1/1 d:\pindah file\college\PI\sawit\test_image.jpg: 640x640 49 healthys, 19 immatures, 111.8ms
# Speed: 3.5ms preprocess, 111.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: '5', 1: 'Grass', 2: 'healthy', 3: 'immature', 4: 'stressed', 5: 'unhealthy'}
#  obb: None
#  orig_img: array([[[ 70, 106,  92],
#          [ 77, 113,  99],
#          [ 82, 118, 104],
#          ...,
#          [ 78, 114, 108],
#          [ 71, 107, 101],
#          [ 64, 100,  94]],
#
#         [[ 63,  99,  87],
#          [ 71, 107,  93],
#          [ 78, 114, 102],
#          ...,
#          [ 77, 113, 107],
#          [ 73, 109, 103],
#          [ 68, 104,  98]],
#
#         [[ 58,  95,  85],
#          [ 66, 104,  92],
#          [ 73, 110, 100],
#          ...,
#          [ 76, 112, 106],
#          [ 75, 111, 105],
#          [ 74, 110, 104]],
#
#         ...,
#
#         [[ 66, 100,  76],
#          [ 70, 104,  80],
#          [ 71, 106,  80],
#          ...,
#          [ 78,  98,  93],
#          [ 67,  87,  82],
#          [ 66,  88,  83]],
#
#         [[ 74, 108,  84],
#          [ 75, 109,  85],
#          [ 72, 107,  81],
#          ...,
#          [ 80, 100,  95],
#          [ 71,  92,  84],
#          [ 65,  88,  80]],
#
#         [[ 81, 115,  91],
#          [ 82, 116,  92],
#          [ 78, 113,  87],
#          ...,
#          [ 84, 104,  99],
#          [ 77,  98,  90],
#          [ 69,  92,  84]]], shape=(640, 640, 3), dtype=uint8)
#  orig_shape: (640, 640)
#  path: 'd:\\pindah file\\college\\PI\\sawit\\test_image.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict'
#  speed: {'preprocess': 3.5321000032126904, 'inference': 111.83080030605197, 'postprocess': 1.1421004310250282}]

# %%
for r in results:
    im_bgr = r.plot()                   # Gambar dengan bounding box
    im_rgb = cv2.cvtColor(im_bgr, cv2.COLOR_BGR2RGB)
    plt.imshow(im_rgb)
    plt.axis('off')
    plt.show()

# %%
output_path = "output.png"
cv2.imwrite(output_path, im_bgr)
print(f"Hasil disimpan di: {output_path}")
# Out:
# Hasil disimpan di: output.png
