# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# %%
model = YOLO("yolov12_sawit_v2.pt")
model.export(format="torchscript")
# Out:
# Ultralytics 8.3.160  Python-3.11.9 torch-2.7.1+cpu CPU (13th Gen Intel Core(TM) i7-13620H)
#
# PyTorch: starting from 'yolov12_sawit_v2.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 9, 8400) (5.1 MB)
#
# TorchScript: starting export with torch 2.7.1+cpu...
# TorchScript: export success  2.3s, saved as 'yolov12_sawit_v2.torchscript' (10.5 MB)
#
# Export complete (2.6s)
# Results saved to D:\pindah file\college\PI\sawit
# Predict:         yolo predict task=detect model=yolov12_sawit_v2.torchscript imgsz=640
# Validate:        yolo val task=detect model=yolov12_sawit_v2.torchscript imgsz=640 data=/kaggle/working/Oil palm tree Health detection.v3i.yolov12_no augmentation/data.yaml
# Visualize:       https://netron.app
# 'yolov12_sawit_v2.torchscript'

# %%
image_path = "test_image.jpg"

# %%
results = model(image_path)
results
# Out:
# image 1/1 d:\pindah file\college\PI\sawit\test_image.jpg: 640x640 49 Healthys, 19 Smalls, 87.1ms
# Speed: 3.7ms preprocess, 87.1ms inference, 14.7ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Dead', 1: 'Grass', 2: 'Healthy', 3: 'Small', 4: 'Yellow'}
#  obb: None
#  orig_img: array([[[ 70, 106,  92],
#          [ 77, 113,  99],
#          [ 82, 118, 104],
#          ...,
#          [ 78, 114, 108],
#          [ 71, 107, 101],
#          [ 64, 100,  94]],
#
#         [[ 63,  99,  87],
#          [ 71, 107,  93],
#          [ 78, 114, 102],
#          ...,
#          [ 77, 113, 107],
#          [ 73, 109, 103],
#          [ 68, 104,  98]],
#
#         [[ 58,  95,  85],
#          [ 66, 104,  92],
#          [ 73, 110, 100],
#          ...,
#          [ 76, 112, 106],
#          [ 75, 111, 105],
#          [ 74, 110, 104]],
#
#         ...,
#
#         [[ 66, 100,  76],
#          [ 70, 104,  80],
#          [ 71, 106,  80],
#          ...,
#          [ 78,  98,  93],
#          [ 67,  87,  82],
#          [ 66,  88,  83]],
#
#         [[ 74, 108,  84],
#          [ 75, 109,  85],
#          [ 72, 107,  81],
#          ...,
#          [ 80, 100,  95],
#          [ 71,  92,  84],
#          [ 65,  88,  80]],
#
#         [[ 81, 115,  91],
#          [ 82, 116,  92],
#          [ 78, 113,  87],
#          ...,
#          [ 84, 104,  99],
#          [ 77,  98,  90],
#          [ 69,  92,  84]]], shape=(640, 640, 3), dtype=uint8)
#  orig_shape: (640, 640)
#  path: 'd:\\pindah file\\college\\PI\\sawit\\test_image.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict'
#  speed: {'preprocess': 3.6712996661663055, 'inference': 87.11580000817776, 'postprocess': 14.73330007866025}]

# %%
for r in results:
    im_bgr = r.plot()                   # Gambar dengan bounding box
    im_rgb = cv2.cvtColor(im_bgr, cv2.COLOR_BGR2RGB)
    plt.imshow(im_rgb)
    plt.axis('off')
    plt.show()

# %%
output_path = "output.png"
cv2.imwrite(output_path, im_bgr)
print(f"Hasil disimpan di: {output_path}")
# Out:
# Hasil disimpan di: output.png
